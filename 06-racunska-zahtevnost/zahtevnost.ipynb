# %%
import stopaj

# %%
import sled

# %%
stopaj.izmeri_case_poskusov(
    [stopaj.nakljucna_matrika(50 * n) for n in range(1, 20)],
    [sled.sled_matrike1, sled.sled_matrike2],
)
# Out:
# sled_matrike1...................
# sled_matrike2...................
